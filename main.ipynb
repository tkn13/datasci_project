# %% [markdown]
# <a href="https://colab.research.google.com/github/tkn13/datasci_project/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tkn13/datasci_project
# %cd datasci_project
# Out:
# fatal: destination path 'datasci_project' already exists and is not an empty directory.
# /content/datasci_project

# %%
import sys
sys.path.append('/content/datasci_project')

# %%
import utils

utils.get_connection()
# Out:
# Mounted at /content/drive
# '/content/drive/My Drive/datasci_dataset/'

# %%
df = utils.load_data()
# Out:
# Loading data_raw.csv...

# %%
df.head()
# Out:
#    ID  Old  Driving_experience  Distribution_channel  Policies_in_force  \
# 0   3   40                  20                     0                  1
# 1   3   41                  21                     0                  1
# 2   3   42                  22                     0                  1
# 3   3   43                  23                     0                  1
# 4   6   49                  25                     0                  1
#
#    Max_policies  Max_products  Lapse  Payment  Cost_claims_year  ...  Power  \
# 0             2             1      0        0               0.0  ...     85
# 1             2             1      0        0               0.0  ...     85
# 2             2             1      0        0               0.0  ...     85
# 3             2             1      0        0               0.0  ...     85
# 4             2             2      0        0               0.0  ...     87
#
#    Cylinder_capacity  Value_vehicle  N_doors  Type_fuel  Length  Weight  \
# ...
